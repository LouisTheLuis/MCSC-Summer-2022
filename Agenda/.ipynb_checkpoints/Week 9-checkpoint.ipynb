# %% [markdown]
# # Week 9

# %% [markdown]
# ## Objectives so far
# * Code a graph generator for Unity
# * Code force fields in Unity
# * ~~Code Lennard-Jones forces for polymer chain entanglement~~
# * Start working on a RL backbone for the bead model

# %% [markdown]
# ## August 8
#
# Today I work on the bonded and non-bonded interactions again. I expect to be finished with it as soon as it is possible.
#
# In the construction of the implementation of the bonded interactions I encountered some struggle regarding how to derivate these potential equations in order to code them. Unfortunately, the result was as follows for the dihedral potential:
#
# ![image.png](attachment:image.png)
#
# The link attached describes a [very painful way to derive the force equation from this derivative](https://wanglab.hosted.uark.edu/DLPOLY2/node49.html#:~:text=The%20dihedral%20angle%20potentials%20describe,specification%20of%20four%20atomic%20positions). GROMACS had an interesting description on how to implement these without using derivatives.
#
#
# ### Meeting (8/8/2022 - 3:00pm)
#
# We agreed regarding at what time we will practice our presentations. In particular, we decided to practice the next day: Monday, at 10:00am. The presentations would have some slides to be prepared, which would be sent next day by 12:00am.

# %% [markdown]
# ## August 9
#
# Overall, continued working with the potentials. Finished the backbone of the implementation of the bonded interactions; in the process, using a very nice graph search algorithm! As you can see right below I transformed the polymer chain into an undirected graph and then iterated through it to find the groups of 4 atoms that formed dihedrals.
#
# ![image.png](attachment:image.png)
#
# Now the only problem is the implementation of the dihedrals. Also, in addition to this, there is a very visible lack of information in the implementation of the parameters as the MARTINI coarse-graining of cellulose fiber is not the same as the coarse-graining of acetyl cellulose...

# %% [markdown]
# ## August 10
#
# Tried to solve the matrix derivatives of the bonded dihedral; wasn't succesful. I pushed the code to Github and asked Andy to check it out. Hopefully his revision will yield some results and will work out fine in the simulation.
#
# I should start planning the RL backbone of the architecture.

# %% [markdown]
# ## August 11
#
# We had an entire day of presentations! My slides can be seen [here](https://docs.google.com/presentation/d/1iWYQyk413iAi-VzIuxCc0CQeZfY-1lvX-rD9cxjTEQw/edit). Not much was done outside of this.

# %% [markdown]
# ## August 12
#
# ### Meeting (8/12/2022 - 10:00am)
#
# On this meeting Paloma asked us whether we were willing to keep doing the UROP through the Fall. I said yes; although apparently Elena and Jehan are leaving. In addition to this, I was asked whether I could keep working on this hybrid project between computer science and chemical engineering. I had no problem with this as long as I could consult someone who could confirm and fill my shortcomings.
#
# In addition to this, Paloma presented us the possibility to start writing a paper for a conference; in particular, the International Conference on Learning Representations (ICLR). The abstract has to be submitted by September 21st, and the rest has to be submitted by September 28th. The details are [here](https://iclr.cc/Conferences/2023/CallForPapers).
#
# During the rest of the day I decided to revise ML-Agents again to see how to implement it with the current model.
